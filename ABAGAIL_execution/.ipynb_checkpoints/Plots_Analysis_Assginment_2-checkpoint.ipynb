# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Four-peaks

# %% [markdown]
# ### Reading values from CSV files (output of the Jython code)

# %%
# RHC
fp_rhc=pd.read_csv("fourpeaks_rhc.csv",header=None,sep=" ")
fp_rhc=fp_rhc.T
fp_rhc.columns=['Iterations','Fitness','Time']

# SA
fp_sa=pd.read_csv("fourpeaks_sa.csv",header=None,sep=" ")
fp_sa=fp_sa.T
fp_sa.columns=['Iterations','Fitness','Time']

# GA
fp_ga=pd.read_csv("fourpeaks_ga.csv",header=None,sep=" ")
fp_ga=fp_ga.T
fp_ga.columns=['Iterations','Fitness','Time']

# MIMIC
fp_mimic=pd.read_csv("fourpeaks_mimic.csv",header=None,sep=" ")
fp_mimic=fp_mimic.T
fp_mimic.columns=['Iterations','Fitness','Time']

# %% [markdown]
# ### Plotting Compute Clock Time

# %%
plt.figure(figsize=(8,5))
plt.semilogx(fp_rhc['Iterations'],fp_rhc['Time'],c='blue')
plt.semilogx(fp_sa['Iterations'],fp_sa['Time'],c='green')
plt.semilogx(fp_ga['Iterations'],fp_ga['Time'],c='red')
plt.semilogx(fp_mimic['Iterations'],fp_mimic['Time'],c='k')
plt.grid(True)
plt.title("Compute clock time in $\mathbf{Four-peaks}$ problem",fontsize=16)
plt.xlabel("Number of iterations",fontsize=15)
plt.ylabel("Clock time (milliseconds)",fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.legend(["Random Hill Climb","Simulated Annealing","Genetic Algorithm","MIMIC"],fontsize=13)
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.loglog(fp_rhc['Iterations'],fp_rhc['Time'],c='blue')
plt.loglog(fp_sa['Iterations'],fp_sa['Time'],c='green')
plt.loglog(fp_ga['Iterations'],fp_ga['Time'],c='red')
plt.loglog(fp_mimic['Iterations'],fp_mimic['Time'],c='k')
plt.grid(True)
plt.title("Compute clock time in $\mathbf{Four-peaks}$ problem",fontsize=16)
plt.xlabel("Number of iterations",fontsize=15)
plt.ylabel("Clock time (milliseconds)",fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.legend(["Random Hill Climb","Simulated Annealing","Genetic Algorithm","MIMIC"],fontsize=13)
plt.show()

# %% [markdown]
# ### Plotting Fitness Score

# %%
plt.figure(figsize=(8,5))
plt.semilogx(fp_rhc['Iterations'],fp_rhc['Fitness'],c='blue')
plt.semilogx(fp_sa['Iterations'],fp_sa['Fitness'],c='green')
plt.semilogx(fp_ga['Iterations'],fp_ga['Fitness'],c='red')
plt.semilogx(fp_mimic['Iterations'],fp_mimic['Fitness'],c='k')
plt.grid(True)
plt.title("Fitness score in $\mathbf{Four-peaks}$ problem",fontsize=16)
plt.xlabel("Number of iterations",fontsize=15)
plt.ylabel("Fitness score",fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.legend(["Random Hill Climb","Simulated Annealing","Genetic Algorithm","MIMIC"],fontsize=13)
plt.show()

# %%
plt.semilogy(fp_rhc['Fitness']/fp_rhc['Time'],c='blue')
plt.semilogy(fp_sa['Fitness']/fp_sa['Time'],c='green')
plt.semilogy(fp_ga['Fitness']/fp_ga['Time'],c='red')
plt.semilogy(fp_mimic['Fitness']/fp_mimic['Time'],c='k')
plt.legend(["Random Hill Climb","Simulated Annealing","Genetic Algorithm","MIMIC"],loc=3)
plt.show()

# %% [markdown]
# # Knapsack

# %% [markdown]
# ### Reading values from CSV files (output of the Jython code)

# %%
# RHC
knapsack_rhc=pd.read_csv("knapsack_rhc.csv",header=None,sep=" ")
knapsack_rhc=knapsack_rhc.T
knapsack_rhc.columns=['Iterations','Fitness','Time']

# SA
knapsack_sa=pd.read_csv("knapsack_sa.csv",header=None,sep=" ")
knapsack_sa=knapsack_sa.T
knapsack_sa.columns=['Iterations','Fitness','Time']

# GA
knapsack_ga=pd.read_csv("knapsack_ga.csv",header=None,sep=" ")
knapsack_ga=knapsack_ga.T
knapsack_ga.columns=['Iterations','Fitness','Time']

# MIMIC
knapsack_mimic=pd.read_csv("knapsack_mimic.csv",header=None,sep=" ")
knapsack_mimic=knapsack_mimic.T
knapsack_mimic.columns=['Iterations','Fitness','Time']

# %% [markdown]
# ### Plotting compute clock time

# %%
plt.figure(figsize=(8,5))
plt.loglog(knapsack_rhc['Iterations'],knapsack_rhc['Time'],c='blue')
plt.loglog(knapsack_sa['Iterations'],knapsack_sa['Time'],c='green')
plt.loglog(knapsack_ga['Iterations'],knapsack_ga['Time'],c='red')
plt.loglog(knapsack_mimic['Iterations'],knapsack_mimic['Time'],c='k')
plt.grid(True)
plt.title("Compute clock time in $\mathbf{Knapsack}$ problem",fontsize=16)
plt.xlabel("Number of iterations",fontsize=15)
plt.ylabel("Clock time (milliseconds)",fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.legend(["Random Hill Climb","Simulated Annealing","Genetic Algorithm","MIMIC"],fontsize=13)
plt.show()

# %% [markdown]
# ### Plotting Fitness Score

# %%
plt.figure(figsize=(8,5))
plt.semilogx(knapsack_rhc['Iterations'],knapsack_rhc['Fitness'],c='blue')
plt.semilogx(knapsack_sa['Iterations'],knapsack_sa['Fitness'],c='green')
plt.semilogx(knapsack_ga['Iterations'],knapsack_ga['Fitness'],c='red')
plt.semilogx(knapsack_mimic['Iterations'],knapsack_mimic['Fitness'],c='k')
plt.grid(True)
plt.title("Fitness score in $\mathbf{Knapsack}$ problem",fontsize=16)
plt.xlabel("Number of iterations",fontsize=15)
plt.ylabel("Fitness score",fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.legend(["Random Hill Climb","Simulated Annealing","Genetic Algorithm","MIMIC"],fontsize=13)
plt.show()

# %% [markdown]
# # Traveling Salesperson

# %% [markdown]
# ### Reading values from CSV files (output of the Jython code)

# %%
# RHC
tsp_rhc=pd.read_csv("tsp_rhc.csv",header=None,sep=" ")
tsp_rhc=tsp_rhc.T
tsp_rhc.columns=['Iterations','Fitness','Time']

# SA
tsp_sa=pd.read_csv("tsp_sa.csv",header=None,sep=" ")
tsp_sa=tsp_sa.T
tsp_sa.columns=['Iterations','Fitness','Time']

# GA
tsp_ga=pd.read_csv("tsp_ga.csv",header=None,sep=" ")
tsp_ga=tsp_ga.T
tsp_ga.columns=['Iterations','Fitness','Time']

# MIMIC
tsp_mimic=pd.read_csv("tsp_mimic.csv",header=None,sep=" ")
tsp_mimic=tsp_mimic.T
tsp_mimic.columns=['Iterations','Fitness','Time']

# %% [markdown]
# ### Plotting compute clock time

# %%
plt.figure(figsize=(8,5))
plt.loglog(tsp_rhc['Iterations'],tsp_rhc['Time'],c='blue')
plt.loglog(tsp_sa['Iterations'],tsp_sa['Time'],c='green')
plt.loglog(tsp_ga['Iterations'],tsp_ga['Time'],c='red')
plt.loglog(tsp_mimic['Iterations'],tsp_mimic['Time'],c='k')
plt.grid(True)
plt.title("Compute clock time in $\mathbf{Traveling\ Salesperson}$ problem",fontsize=16)
plt.xlabel("Number of iterations",fontsize=15)
plt.ylabel("Clock time (milliseconds)",fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.legend(["Random Hill Climb","Simulated Annealing","Genetic Algorithm","MIMIC"],fontsize=13)
plt.show()

# %% [markdown]
# ### Plotting Fitness Score (Inverse of distance travelled)

# %%
plt.figure(figsize=(8,5))
plt.semilogx(tsp_rhc['Iterations'],tsp_rhc['Fitness'],c='blue')
plt.semilogx(tsp_sa['Iterations'],tsp_sa['Fitness'],c='green')
plt.semilogx(tsp_ga['Iterations'],tsp_ga['Fitness'],c='red')
plt.semilogx(tsp_mimic['Iterations'],tsp_mimic['Fitness'],c='k')
plt.grid(True)
plt.title("Fitness score in $\mathbf{Traveling \ Salesperson}$ problem",fontsize=16)
plt.xlabel("Number of iterations",fontsize=15)
plt.ylabel("Inverse of total path length",fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.legend(["Random Hill Climb","Simulated Annealing","Genetic Algorithm","MIMIC"],fontsize=13)
plt.show()

# %%
# MIMIC
knapsack_mimic1=pd.read_csv("knapsack_mimic.csv",header=None,sep=" ")
knapsack_mimic1=knapsack_mimic1.T
knapsack_mimic1.columns=['Iterations','Fitness','Time']

# %%
knapsack_mimic1[['Fitness','Time']]
# Out:
#         Fitness   Time
# 0   4949.060994  147.0
# 1   4956.509587  202.0
# 2   4956.509587  194.0
# 3   4956.509587  243.0
# 4   4956.509587  245.0
# 5   4956.509587  252.0
# 6   4961.146678  283.0
# 7   4970.694328  332.0
# 8   4963.653083  363.0
# 9   4970.745454  405.0
# 10  4956.714089  443.0
# 11  4971.847034  491.0
# 12  4964.609024  527.0
# 13  4963.755335  587.0
# 14  4956.662964  602.0
# 15  4970.847705  642.0
# 16  4956.714089  679.0
# 17  4967.076821  724.0
# 18  4963.755335  765.0
# 19  4970.847705  810.0

# %%
# GA
tsp_ga1=pd.read_csv("tsp_ga.csv",header=None,sep=" ")
tsp_ga1=tsp_ga1.T
tsp_ga1.columns=['Iterations','Fitness','Time']

# %%
tsp_ga1
# Out:
#     Iterations   Fitness    Time
# 0         10.0  0.070375    11.0
# 1         17.0  0.092124    12.0
# 2         31.0  0.123143    17.0
# 3         56.0  0.129487    29.0
# 4        100.0  0.139994    32.0
# 5        177.0  0.127261    65.0
# 6        316.0  0.128319    85.0
# 7        562.0  0.138999    76.0
# 8       1000.0  0.136834   114.0
# 9       1778.0  0.142760   165.0
# 10      3162.0  0.139657   259.0
# 11      5623.0  0.142636   420.0
# 12     10000.0  0.139265   728.0
# 13     17782.0  0.136983  1315.0
# 14     31622.0  0.136326  2223.0
# 15     56234.0  0.142130  3968.0
# 16    100000.0  0.143331  6999.0

# %%
# SA
fp_sa1=pd.read_csv("fourpeaks_sa.csv",header=None,sep=" ")
fp_sa1=fp_sa1.T
fp_sa1.columns=['Iterations','Fitness','Time']

# %%
fp_sa1
# Out:
#     Iterations  Fitness    Time
# 0         31.0      0.0     1.0
# 1         56.0      1.0     1.0
# 2        100.0      1.0     1.0
# 3        177.0      1.0     3.0
# 4        316.0      3.0     4.0
# 5        562.0      6.0     4.0
# 6       1000.0      7.0     8.0
# 7       1778.0     22.0     3.0
# 8       3162.0     54.0    10.0
# 9       5623.0     76.0    14.0
# 10     10000.0    149.0    27.0
# 11     17782.0    200.0    63.0
# 12     31622.0    200.0    61.0
# 13     56234.0    200.0    96.0
# 14    100000.0    200.0   183.0
# 15    177827.0    200.0   307.0
# 16    316227.0    200.0   473.0
# 17    562341.0    200.0   829.0
# 18   1000000.0    200.0  1472.0
# 19   1778279.0    200.0  2585.0
